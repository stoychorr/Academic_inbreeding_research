# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Stoycho.rusinov\AppData\Local\anaconda3\python.exe

# %%
import sys

# install the package into this kernel's Python
!"{sys.executable}" -m pip install --upgrade pip
!"{sys.executable}" -m pip install playwright

# install the browser binaries Playwright needs
!"{sys.executable}" -m playwright install
# Out:
# Requirement already satisfied: pip in C:\Users\Stoycho.rusinov\AppData\Local\anaconda3\Lib\site-packages (26.0.1)
# Requirement already satisfied: playwright in C:\Users\Stoycho.rusinov\AppData\Local\anaconda3\Lib\site-packages (1.58.0)
# Requirement already satisfied: pyee<14,>=13 in C:\Users\Stoycho.rusinov\AppData\Local\anaconda3\Lib\site-packages (from playwright) (13.0.1)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in C:\Users\Stoycho.rusinov\AppData\Local\anaconda3\Lib\site-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in C:\Users\Stoycho.rusinov\AppData\Local\anaconda3\Lib\site-packages (from pyee<14,>=13->playwright) (4.15.0)

# %%
import sys, asyncio

if sys.platform.startswith("win"):
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

# %%
import sys, asyncio, threading

def run_coro_in_thread(coro):
    err = {}
    def runner():
        try:
            if sys.platform.startswith("win"):
                asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
            asyncio.run(coro)
        except Exception as e:
            err["e"] = e

    t = threading.Thread(target=runner, daemon=True)
    t.start()
    t.join()

    if "e" in err:
        raise err["e"]

# %%
import pandas as pd
from pathlib import Path

candidates = [
    Path("inbreeding_at_FPhys.xlsx")
]

path = next((p for p in candidates if p.exists()), None)
if path is None:
    raise FileNotFoundError("Couldn't find inbreeding_at_FPhys.{xlsx,xlsm,xls} in the current folder.")

df = pd.read_excel(path, sheet_name="main_database")
df.columns = df.columns.astype(str).str.strip()

df["NACID"] = df["NACID"].astype(str).str.strip()
df_links = df[["NACID"]].copy()
df_links = df_links[df_links["NACID"].str.contains("ras.nacid.bg", na=False)].copy()

print("Loaded:", path.name, "| rows:", len(df), "| NACID links:", len(df_links))
df_links.head(10)
# Out:
# Loaded: inbreeding_at_FPhys.xlsx | rows: 149 | NACID links: 112
#                                               NACID
# 0   https://ras.nacid.bg/dissertation-preview/25762
# 1   https://ras.nacid.bg/dissertation-preview/22992
# 2   https://ras.nacid.bg/dissertation-preview/27215
# 3   https://ras.nacid.bg/dissertation-preview/25775
# 4   https://ras.nacid.bg/dissertation-preview/41613
# 5   https://ras.nacid.bg/dissertation-preview/39622
# 6   https://ras.nacid.bg/dissertation-preview/46569
# 11  https://ras.nacid.bg/dissertation-preview/27581
# 12   https://ras.nacid.bg/dissertation-preview/2802
# 13   https://ras.nacid.bg/dissertation-preview/2845

# %%
import re
import asyncio
import pandas as pd
from datetime import datetime
from pathlib import Path
from playwright.async_api import async_playwright

# =====================
# SETTINGS (EDIT THESE)
# =====================
FILE = "inbreeding_at_FPhys.xlsx"
SHEET = "main_database"

NAME_COL = "Name"      # <-- CHANGE to your actual name column (e.g. "NAME", "Име", etc.)
LINK_COL = "NACID"

N_PEOPLE = 90
OUTFILE = "FPhys_phd_plus_headers.xlsx"

KEYWORDS = ("Асистент", "Главен асистент", "Доцент", "Професор", "Преподавател")

# =====================
# LOAD EXCEL
# =====================
path = Path(FILE)
if not path.exists():
    raise FileNotFoundError(f"File not found: {path.resolve()}")

df = pd.read_excel(path, sheet_name=SHEET)
df.columns = df.columns.astype(str).str.strip()

if LINK_COL not in df.columns:
    raise KeyError(f"Missing column '{LINK_COL}'. Columns present: {list(df.columns)}")

if NAME_COL not in df.columns:
    raise KeyError(
        f"Missing name column '{NAME_COL}'. "
        f"Set NAME_COL to one of: {list(df.columns)}"
    )

df[LINK_COL] = df[LINK_COL].astype(str).str.strip()
df[NAME_COL] = df[NAME_COL].astype(str).str.strip()

df = df[df[LINK_COL].str.contains("ras.nacid.bg", na=False)].copy()

# =====================
# HELPERS
# =====================
def norm(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "")).strip()

def clean_header_prefix(s: str) -> str:
    s = norm(s)
    return re.sub(r'^[^A-Za-zА-Яа-я0-9"„]+', "", s).strip()

def first_date(text: str):
    m = re.search(r"\b(\d{1,2}\.\d{1,2}\.\d{4})\b", text or "")
    return m.group(1) if m else None

def grab_stop(label_no_colon, text):
    labels = [
        "Висше училище", "Факултет", "Първично звено", "Научна степен",
        "Професионално направление", "Диплома No/дата", "Тема на дисертационния труд"
    ]
    nxt = "|".join(map(re.escape, labels))
    m = re.search(
        rf"{re.escape(label_no_colon)}\s*:\s*(.*?)(?=\s*(?:{nxt})\s*:|$)",
        text or "",
        flags=re.S
    )
    return norm(m.group(1)) if m else None

def award_date_from_diploma(text: str):
    line = grab_stop("Диплома No/дата", text)
    return first_date(line)

def sort_date(text):
    pattern = r'\d{1,2}.\d{1,2}.\d{4}'
    match = re.search(pattern, text)
    return datetime.strptime(match.group(), "%d.%m.%Y")

# =====================
# POSITIONS HEADER EXTRACTOR (NON-CLICK)
# =====================
async def get_section_container(page, section_title: str, exact):
    title_el = page.get_by_text(section_title, exact=exact).first
    await title_el.wait_for(timeout=60000)

    section = title_el.locator("xpath=ancestor::div[contains(@class,'card')][1]")
    if await section.count() == 0:
        section = title_el.locator("xpath=ancestor::div[2]")
    return section.first

async def find_position_headers(section):
    locators = [
        section.locator("css=mat-expansion-panel-header"),
        section.locator("css=.mat-expansion-panel-header"),
        section.locator("css=mat-expansion-panel .mat-expansion-panel-header"),
        section.locator("css=mat-expansion-panel [role='button']"),
        section.locator("css=[role='button']"),
    ]
    for loc in locators:
        try:
            if await loc.count() > 0:
                return loc
        except Exception:
            continue
    return section.locator("xpath=.//*")

def canonical_header(s: str) -> str:
    s = clean_header_prefix(s)
    s = norm(s)

    # If the string accidentally contains multiple headers glued together,
    # keep only the first plausible one: "<Rank> - <Institution...>"
    # (stop at the next rank keyword if it appears again)
    for k in KEYWORDS:
        # if we see a second keyword later in the string, cut before it
        m = re.search(rf"\s({re.escape(k)}\s*-)", s)
        if m and m.start() > 0:
            s = s[:m.start()].strip()

    return s

async def get_headers_in_section(page, section_title: str):
    section = await get_section_container(page, section_title, False)
    await section.scroll_into_view_if_needed()
    await asyncio.sleep(0.2)

    # Prefer the true header element; fall back to class
    headers_loc = section.locator("css=mat-expansion-panel-header, .mat-expansion-panel-header")
    if await headers_loc.count() == 0:
        headers_loc = await find_position_headers(section)

    n = await headers_loc.count()

    out = []
    seen_keys = set()

    for i in range(n):
        h = headers_loc.nth(i)
        raw = norm(await h.inner_text())
        if not raw:
            continue

        # keep only header-like lines
        if " - " not in raw:
            continue

        cleaned = canonical_header(raw)
        if not cleaned:
            continue
        if not any(cleaned.startswith(k) for k in KEYWORDS):
            continue

        key = cleaned.lower()
        if key in seen_keys:
            continue
        seen_keys.add(key)
        out.append(cleaned)

    return out

async def get_nested_date_in_header(page, header_title : str):
    section = await get_section_container(page, header_title, True)
    await section.scroll_into_view_if_needed()
    await asyncio.sleep(0.2)

    panel_heading_div = section.locator(".panel-heading")
    spanClickable = panel_heading_div.locator('.fa')
    classes = await spanClickable.get_attribute("class")
    expanded = 'fa-chevron-down' in classes

    if expanded != True:
        await spanClickable.click()

    next_div = panel_heading_div.locator("xpath=following-sibling::div[1]")
    headers_loc = next_div.locator(".row")  

    if await headers_loc.count() == 0:
        headers_loc = await find_position_headers(section)

    n = await headers_loc.count()
    seen_keys = set()

    for i in range(n):
        h = headers_loc.nth(i)
        raw = norm(await h.inner_text())
        if not raw:
            continue

        cleaned = canonical_header(raw)

        if not cleaned:
            continue

        key = cleaned.lower()

        if key in seen_keys:
            continue

        seen_keys.add(key)
        pattern = r'\d{1,2}.\d{1,2}.\d{4}'

        if "Номер/дата на акт за назначаване" in cleaned:
            date = re.search(pattern, cleaned)
            return date.group() if date else None

async def safe_goto(page, url, tries = 5):
    for attempt in range(tries):
        try:
            await page.goto(url, wait_until="domcontentloaded", timeout = 60000)
            return True
        except Exception as e:
            msg = str(e)
            if ("ERR_" in msg or "Timeout" in msg):
                await asyncio.sleep(2 * (attempt + 1))
                continue
            raise

    return False
# =====================
# PERSON SCRAPER (PHD + HEADERS)
# =====================
async def scrape_person(page, url: str, row):

    try:
        ok = await safe_goto(page, url, 5)

        if not ok:
            row["ERROR"] = "Error: Timeout waiting for page to be loaded"
            return '', '', '', '', ''
        
    except Exception as e:
        row["ERROR"] = str(e)
        return '', '', '', '', ''
    
    phd = {
        'Phd_Institution': '',
        'PhD_Faculty': '',
        'PhD_PrimaryUnit': '',
        'PhD_Degree': '',
        'PhD_Field': '',
        'PhD_DiplomaNoDate': '',
        'PhD_AwardDate': '',
        'Dissertation_Title': ''
    }

    current_headers = []
    past_headers = []
    current_nested_headers = []
    past_nested_headers = []
         
    try:
        # ----- PhD block -----
        loc = page.locator("h4.panel-title", has_text = "Научни степени")
        await loc.wait_for(state = "visible")
        next_div = loc.locator("xpath=../following-sibling::div[1]")
        divPanels = await next_div.locator("div.panel-default").all()

        for div_panel in divPanels:
            clickable = div_panel.locator('.btn-block')
            await clickable.click()
            await div_panel.get_by_text("Диплома No/дата:", exact=False).wait_for(timeout=60000)

            anchor = div_panel.get_by_text("Диплома No/дата:", exact=False).first
            best_text, best_score = "", -1
            target_labels = [
                "Висше училище:", "Факултет:", "Първично звено:", "Научна степен:",
                "Професионално направление:", "Диплома No/дата:", "Тема на дисертационния труд:"
            ]
            for depth in range(1, 15):
                loc = anchor.locator(f"xpath=ancestor::div[{depth}]")
                if await loc.count() == 0:
                    break
                txt = await loc.first.inner_text()
                score = sum(1 for lab in target_labels if lab in txt)
                if score > best_score:
                    best_score, best_text = score, txt

            phd_block = best_text.replace("\u00a0", " ").strip()

            phd["Phd_Institution"] = phd["Phd_Institution"] + (grab_stop("Висше училище", phd_block) or '') + ' '
            phd["PhD_Faculty"] = phd["PhD_Faculty"] +  (grab_stop("Факултет", phd_block) or '') + ' '
            phd["PhD_PrimaryUnit"] = phd["PhD_PrimaryUnit"] +  (grab_stop("Първично звено", phd_block) or '') + ' '
            phd["PhD_Degree"] = phd["PhD_Degree"] +  (grab_stop("Научна степен", phd_block) or '') + ' '
            phd["PhD_Field"] = phd["PhD_Field"] +  (grab_stop("Професионално направление", phd_block) or '') + ' '
            phd["PhD_DiplomaNoDate"] = phd["PhD_DiplomaNoDate"] +  (grab_stop("Диплома No/дата", phd_block) or '') + ' '
            phd["PhD_AwardDate"] = phd["PhD_AwardDate"] +  (award_date_from_diploma(phd_block) or '') + ' '
            phd["Dissertation_Title"] = phd["Dissertation_Title"] +  (grab_stop("Тема на дисертационния труд", phd_block) or '') + ' '

    except Exception as e:
        row["ERROR"] = row.get("ERROR", " ") + str(e)

    try:
        # ----- Positions headers -----
        current_headers = await get_headers_in_section(page, "Настоящи академични длъжности")
        past_headers = await get_headers_in_section(page, "Заемани академични длъжности")

        current_nested_headers = []
        past_nested_headers = []

        for current_header in current_headers:
            date = await get_nested_date_in_header(page, current_header)
            result = current_header + ', ' + date
            current_nested_headers.append(result)

        for current_past_header in past_headers:
            past_date = await get_nested_date_in_header(page, current_past_header)
            result = current_past_header + ', ' + past_date
            past_nested_headers.append(result)
        
        current_nested_headers = sorted(current_nested_headers, key = sort_date)
        past_nested_headers = sorted(past_nested_headers, key = sort_date)
    except Exception as e:
       row["ERROR"] = row.get("ERROR", " ") + str(e)


    return phd, " | ".join(current_headers), " | ".join(past_headers), " | ".join(current_nested_headers), " | ".join(past_nested_headers)

# =====================
# RUN MANY PEOPLE + SIMPLE PROGRESS
# =====================
# async def run(df):
async def run(df):
    subset = df[[NAME_COL, LINK_COL]].dropna().head(N_PEOPLE).copy()
    rows = []
    total = len(subset)

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        for i, (name, url) in enumerate(zip(subset[NAME_COL], subset[LINK_COL]), start=1):
            print(f"[{i}/{total}] {url}")

            row = {"Name": name, "NACID_URL": url}
            phd, cur_headers, past_headers, cur_nested_headers, past_nested_headers = await scrape_person(page, url, row)
            row.update(phd)
            row["Current_Positions_Headers"] = cur_headers
            row["Past_Positions_Headers"] = past_headers
            row['Current_Positions'] = cur_nested_headers
            row["Past_Positions"] = past_nested_headers
            rows.append(row)
            await asyncio.sleep(0.6)

        await browser.close()

    out = pd.DataFrame(rows)
    out.to_excel(OUTFILE, index=False)
    print(f"\nDONE → {OUTFILE}")

# =====================
# NOTEBOOK RUN
# =====================
run_coro_in_thread(run(df))
# Out:
# [1/90] https://ras.nacid.bg/dissertation-preview/25762
# [2/90] https://ras.nacid.bg/dissertation-preview/22992
# [3/90] https://ras.nacid.bg/dissertation-preview/27215

# %%
import re
import asyncio
import pandas as pd
from datetime import datetime
from pathlib import Path
from playwright.async_api import async_playwright

# =====================
# SETTINGS (EDIT THESE)
# =====================
FILE = "inbreeding_at_FPhys.xlsx"
SHEET = "main_database"

NAME_COL = "Name"      # <-- CHANGE to your actual name column (e.g. "NAME", "Име", etc.)
LINK_COL = "NACID"

N_PEOPLE = 112
OUTFILE = "FPhys_phd_plus_headers.xlsx"

KEYWORDS = ("Асистент", "Главен асистент", "Доцент", "Професор", "Преподавател")

# =====================
# LOAD EXCEL
# =====================
path = Path(FILE)
if not path.exists():
    raise FileNotFoundError(f"File not found: {path.resolve()}")

df = pd.read_excel(path, sheet_name=SHEET)
df.columns = df.columns.astype(str).str.strip()

if LINK_COL not in df.columns:
    raise KeyError(f"Missing column '{LINK_COL}'. Columns present: {list(df.columns)}")

if NAME_COL not in df.columns:
    raise KeyError(
        f"Missing name column '{NAME_COL}'. "
        f"Set NAME_COL to one of: {list(df.columns)}"
    )

df[LINK_COL] = df[LINK_COL].astype(str).str.strip()
df[NAME_COL] = df[NAME_COL].astype(str).str.strip()

df = df[df[LINK_COL].str.contains("ras.nacid.bg", na=False)].copy()

# =====================
# HELPERS
# =====================
def norm(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "")).strip()

def clean_header_prefix(s: str) -> str:
    s = norm(s)
    return re.sub(r'^[^A-Za-zА-Яа-я0-9"„]+', "", s).strip()

def first_date(text: str):
    m = re.search(r"\b(\d{1,2}\.\d{1,2}\.\d{4})\b", text or "")
    return m.group(1) if m else None

def grab_stop(label_no_colon, text):
    labels = [
        "Висше училище", "Факултет", "Първично звено", "Научна степен",
        "Професионално направление", "Диплома No/дата", "Тема на дисертационния труд"
    ]
    nxt = "|".join(map(re.escape, labels))
    m = re.search(
        rf"{re.escape(label_no_colon)}\s*:\s*(.*?)(?=\s*(?:{nxt})\s*:|$)",
        text or "",
        flags=re.S
    )
    return norm(m.group(1)) if m else None

def award_date_from_diploma(text: str):
    line = grab_stop("Диплома No/дата", text)
    return first_date(line)

def sort_date(text):
    pattern = r'\d{1,2}.\d{1,2}.\d{4}'
    match = re.search(pattern, text)
    return datetime.strptime(match.group(), "%d.%m.%Y")

# =====================
# POSITIONS HEADER EXTRACTOR (NON-CLICK)
# =====================
async def get_section_container(page, section_title: str, exact):
    title_el = page.get_by_text(section_title, exact=exact).first
    await title_el.wait_for(timeout=60000)

    section = title_el.locator("xpath=ancestor::div[contains(@class,'card')][1]")
    if await section.count() == 0:
        section = title_el.locator("xpath=ancestor::div[2]")
    return section.first

async def find_position_headers(section):
    locators = [
        section.locator("css=mat-expansion-panel-header"),
        section.locator("css=.mat-expansion-panel-header"),
        section.locator("css=mat-expansion-panel .mat-expansion-panel-header"),
        section.locator("css=mat-expansion-panel [role='button']"),
        section.locator("css=[role='button']"),
    ]
    for loc in locators:
        try:
            if await loc.count() > 0:
                return loc
        except Exception:
            continue
    return section.locator("xpath=.//*")

def canonical_header(s: str) -> str:
    s = clean_header_prefix(s)
    s = norm(s)

    # If the string accidentally contains multiple headers glued together,
    # keep only the first plausible one: "<Rank> - <Institution...>"
    # (stop at the next rank keyword if it appears again)
    for k in KEYWORDS:
        # if we see a second keyword later in the string, cut before it
        m = re.search(rf"\s({re.escape(k)}\s*-)", s)
        if m and m.start() > 0:
            s = s[:m.start()].strip()

    return s

async def get_headers_in_section(page, section_title: str):
    section = await get_section_container(page, section_title, False)
    await section.scroll_into_view_if_needed()
    await asyncio.sleep(0.2)

    # Prefer the true header element; fall back to class
    headers_loc = section.locator("css=mat-expansion-panel-header, .mat-expansion-panel-header")
    if await headers_loc.count() == 0:
        headers_loc = await find_position_headers(section)

    n = await headers_loc.count()

    out = []
    seen_keys = set()

    for i in range(n):
        h = headers_loc.nth(i)
        raw = norm(await h.inner_text())
        if not raw:
            continue

        # keep only header-like lines
        if " - " not in raw:
            continue

        cleaned = canonical_header(raw)
        if not cleaned:
            continue
        if not any(cleaned.startswith(k) for k in KEYWORDS):
            continue

        key = cleaned.lower()
        if key in seen_keys:
            continue
        seen_keys.add(key)
        out.append(cleaned)

    return out

async def get_nested_date_in_header(page, header_title : str):
    section = await get_section_container(page, header_title, True)
    await section.scroll_into_view_if_needed()
    await asyncio.sleep(0.2)

    panel_heading_div = section.locator(".panel-heading")
    spanClickable = panel_heading_div.locator('.fa')
    classes = await spanClickable.get_attribute("class")
    expanded = 'fa-chevron-down' in classes

    if expanded != True:
        await spanClickable.click()

    next_div = panel_heading_div.locator("xpath=following-sibling::div[1]")
    headers_loc = next_div.locator(".row")  

    if await headers_loc.count() == 0:
        headers_loc = await find_position_headers(section)

    n = await headers_loc.count()
    seen_keys = set()

    for i in range(n):
        h = headers_loc.nth(i)
        raw = norm(await h.inner_text())
        if not raw:
            continue

        cleaned = canonical_header(raw)

        if not cleaned:
            continue

        key = cleaned.lower()

        if key in seen_keys:
            continue

        seen_keys.add(key)
        pattern = r'\d{1,2}.\d{1,2}.\d{4}'

        if "Номер/дата на акт за назначаване" in cleaned:
            date = re.search(pattern, cleaned)
            return date.group() if date else None

async def safe_goto(page, url, tries = 5):
    for attempt in range(tries):
        try:
            await page.goto(url, wait_until="domcontentloaded", timeout = 60000)
            return True
        except Exception as e:
            msg = str(e)
            if ("ERR_" in msg or "Timeout" in msg):
                await asyncio.sleep(2 * (attempt + 1))
                continue
            raise

    return False
# =====================
# PERSON SCRAPER (PHD + HEADERS)
# =====================
async def scrape_person(page, url: str, row):

    try:
        ok = await safe_goto(page, url, 5)

        if not ok:
            row["ERROR"] = "Error: Timeout waiting for page to be loaded"
            return '', '', '', '', ''
        
    except Exception as e:
        row["ERROR"] = str(e)
        return '', '', '', '', ''
    
    phd = {
        'Phd_Institution': '',
        'PhD_Faculty': '',
        'PhD_PrimaryUnit': '',
        'PhD_Degree': '',
        'PhD_Field': '',
        'PhD_DiplomaNoDate': '',
        'PhD_AwardDate': '',
        'Dissertation_Title': ''
    }

    current_headers = []
    past_headers = []
    current_nested_headers = []
    past_nested_headers = []
         
    try:
        # ----- PhD block -----
        loc = page.locator("h4.panel-title", has_text = "Научни степени")
        await loc.wait_for(state = "visible")
        next_div = loc.locator("xpath=../following-sibling::div[1]")
        divPanels = await next_div.locator("div.panel-default").all()

        for div_panel in divPanels:
            clickable = div_panel.locator('.btn-block')
            await clickable.click()
            await div_panel.get_by_text("Диплома No/дата:", exact=False).wait_for(timeout=60000)

            anchor = div_panel.get_by_text("Диплома No/дата:", exact=False).first
            best_text, best_score = "", -1
            target_labels = [
                "Висше училище:", "Факултет:", "Първично звено:", "Научна степен:",
                "Професионално направление:", "Диплома No/дата:", "Тема на дисертационния труд:"
            ]
            for depth in range(1, 15):
                loc = anchor.locator(f"xpath=ancestor::div[{depth}]")
                if await loc.count() == 0:
                    break
                txt = await loc.first.inner_text()
                score = sum(1 for lab in target_labels if lab in txt)
                if score > best_score:
                    best_score, best_text = score, txt

            phd_block = best_text.replace("\u00a0", " ").strip()

            phd["Phd_Institution"] = phd["Phd_Institution"] + (grab_stop("Висше училище", phd_block) or '') + ' '
            phd["PhD_Faculty"] = phd["PhD_Faculty"] +  (grab_stop("Факултет", phd_block) or '') + ' '
            phd["PhD_PrimaryUnit"] = phd["PhD_PrimaryUnit"] +  (grab_stop("Първично звено", phd_block) or '') + ' '
            phd["PhD_Degree"] = phd["PhD_Degree"] +  (grab_stop("Научна степен", phd_block) or '') + ' '
            phd["PhD_Field"] = phd["PhD_Field"] +  (grab_stop("Професионално направление", phd_block) or '') + ' '
            phd["PhD_DiplomaNoDate"] = phd["PhD_DiplomaNoDate"] +  (grab_stop("Диплома No/дата", phd_block) or '') + ' '
            phd["PhD_AwardDate"] = phd["PhD_AwardDate"] +  (award_date_from_diploma(phd_block) or '') + ' '
            phd["Dissertation_Title"] = phd["Dissertation_Title"] +  (grab_stop("Тема на дисертационния труд", phd_block) or '') + ' '

    except Exception as e:
        row["ERROR"] = row.get("ERROR", " ") + str(e)

    try:
        # ----- Positions headers -----
        current_headers = await get_headers_in_section(page, "Настоящи академични длъжности")
        past_headers = await get_headers_in_section(page, "Заемани академични длъжности")

        current_nested_headers = []
        past_nested_headers = []

        for current_header in current_headers:
            date = await get_nested_date_in_header(page, current_header)
            result = current_header + ', ' + date
            current_nested_headers.append(result)

        for current_past_header in past_headers:
            past_date = await get_nested_date_in_header(page, current_past_header)
            result = current_past_header + ', ' + past_date
            past_nested_headers.append(result)
        
        current_nested_headers = sorted(current_nested_headers, key = sort_date)
        past_nested_headers = sorted(past_nested_headers, key = sort_date)
    except Exception as e:
       row["ERROR"] = row.get("ERROR", " ") + str(e)


    return phd, " | ".join(current_headers), " | ".join(past_headers), " | ".join(current_nested_headers), " | ".join(past_nested_headers)

# =====================
# RUN MANY PEOPLE + SIMPLE PROGRESS
# =====================
# async def run(df):
async def run(df):
    subset = df[[NAME_COL, LINK_COL]].dropna().head(N_PEOPLE).copy()
    rows = []
    total = len(subset)

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        for i, (name, url) in enumerate(zip(subset[NAME_COL], subset[LINK_COL]), start=1):
            print(f"[{i}/{total}] {url}")

            row = {"Name": name, "NACID_URL": url}
            phd, cur_headers, past_headers, cur_nested_headers, past_nested_headers = await scrape_person(page, url, row)
            row.update(phd)
            row["Current_Positions_Headers"] = cur_headers
            row["Past_Positions_Headers"] = past_headers
            row['Current_Positions'] = cur_nested_headers
            row["Past_Positions"] = past_nested_headers
            rows.append(row)
            await asyncio.sleep(0.6)

        await browser.close()

    out = pd.DataFrame(rows)
    out.to_excel(OUTFILE, index=False)
    print(f"\nDONE → {OUTFILE}")

# =====================
# NOTEBOOK RUN
# =====================
run_coro_in_thread(run(df))
# Out:
# [1/112] https://ras.nacid.bg/dissertation-preview/25762
# [2/112] https://ras.nacid.bg/dissertation-preview/22992
# [3/112] https://ras.nacid.bg/dissertation-preview/27215
# [4/112] https://ras.nacid.bg/dissertation-preview/25775
# [5/112] https://ras.nacid.bg/dissertation-preview/41613
# [6/112] https://ras.nacid.bg/dissertation-preview/39622
# [7/112] https://ras.nacid.bg/dissertation-preview/46569
# [8/112] https://ras.nacid.bg/dissertation-preview/27581
# [9/112] https://ras.nacid.bg/dissertation-preview/2802
# [10/112] https://ras.nacid.bg/dissertation-preview/2845
# [11/112] https://ras.nacid.bg/dissertation-preview/26249
# [12/112] https://ras.nacid.bg/dissertation-preview/36894
# [13/112] https://ras.nacid.bg/dissertation-preview/29890
# [14/112] https://ras.nacid.bg/dissertation-preview/30909
# [15/112] https://ras.nacid.bg/dissertation-preview/27272
# [16/112] https://ras.nacid.bg/dissertation-preview/25773
# [17/112] https://ras.nacid.bg/dissertation-preview/38604
# [18/112] https://ras.nacid.bg/dissertation-preview/39240
# [19/112] https://ras.nacid.bg/dissertation-preview/47985
# [20/112] https://ras.nacid.bg/dissertation-preview/36963
# [21/112] https://ras.nacid.bg/dissertation-preview/42599
# [22/112] https://ras.nacid.bg/dissertation-preview/41142
# [23/112] https://ras.nacid.bg/dissertation-preview/66774
# [24/112] https://ras.nacid.bg/dissertation-preview/23127
# [25/112] https://ras.nacid.bg/dissertation-preview/15245
# [26/112] https://ras.nacid.bg/dissertation-preview/43809
# [27/112] https://ras.nacid.bg/dissertation-preview/40778
# [28/112] https://ras.nacid.bg/dissertation-preview/41739
# [29/112] https://ras.nacid.bg/dissertation-preview/66989
# [30/112] https://ras.nacid.bg/dissertation-preview/27406
# [31/112] https://ras.nacid.bg/dissertation-preview/3567
# [32/112] https://ras.nacid.bg/dissertation-preview/25569
# [33/112] https://ras.nacid.bg/dissertation-preview/40438
# [34/112] https://ras.nacid.bg/dissertation-preview/29880
# [35/112] https://ras.nacid.bg/dissertation-preview/23391
# [36/112] https://ras.nacid.bg/dissertation-preview/28965
# [37/112] https://ras.nacid.bg/dissertation-preview/39762
# [38/112] https://ras.nacid.bg/dissertation-preview/39761
# [39/112] https://ras.nacid.bg/dissertation-preview/41494
# [40/112] https://ras.nacid.bg/dissertation-preview/49309
# [41/112] https://ras.nacid.bg/dissertation-preview/44555
# [42/112] https://ras.nacid.bg/dissertation-preview/27621
# [43/112] https://ras.nacid.bg/dissertation-preview/26967
# [44/112] https://ras.nacid.bg/dissertation-preview/45784
# [45/112] https://ras.nacid.bg/dissertation-preview/68416
# [46/112] https://ras.nacid.bg/dissertation-preview/46236
# [47/112] https://ras.nacid.bg/dissertation-preview/73548
# [48/112] https://ras.nacid.bg/dissertation-preview/39760
# [49/112] https://ras.nacid.bg/dissertation-preview/23230
# [50/112] https://ras.nacid.bg/dissertation-preview/44059
# [51/112] https://ras.nacid.bg/dissertation-preview/40063
# [52/112] https://ras.nacid.bg/dissertation-preview/29256
# [53/112] https://ras.nacid.bg/dissertation-preview/47986
# [54/112] https://ras.nacid.bg/dissertation-preview/67371
# [55/112] https://ras.nacid.bg/dissertation-preview/60052
# [56/112] https://ras.nacid.bg/dissertation-preview/37219
# [57/112] https://ras.nacid.bg/dissertation-preview/3218
# [58/112] https://ras.nacid.bg/dissertation-preview/28336
# [59/112] https://ras.nacid.bg/dissertation-preview/23227
# [60/112] https://ras.nacid.bg/dissertation-preview/29269
# [61/112] https://ras.nacid.bg/dissertation-preview/26225
# [62/112] https://ras.nacid.bg/dissertation-preview/28636
# [63/112] https://ras.nacid.bg/dissertation-preview/37129
# [64/112] https://ras.nacid.bg/dissertation-preview/46231
# [65/112] https://ras.nacid.bg/dissertation-preview/42444
# [66/112] https://ras.nacid.bg/dissertation-preview/55411
# [67/112] https://ras.nacid.bg/dissertation-preview/76550
# [68/112] https://ras.nacid.bg/dissertation-preview/70342
# [69/112] https://ras.nacid.bg/dissertation-preview/69723
# [70/112] https://ras.nacid.bg/dissertation-preview/29899
# [71/112] https://ras.nacid.bg/dissertation-preview/23636
# [72/112] https://ras.nacid.bg/dissertation-preview/23832
# [73/112] https://ras.nacid.bg/dissertation-preview/27472
# [74/112] https://ras.nacid.bg/dissertation-preview/26250
# [75/112] https://ras.nacid.bg/dissertation-preview/46065
# [76/112] https://ras.nacid.bg/dissertation-preview/43571
# [77/112] https://ras.nacid.bg/dissertation-preview/44359
# [78/112] https://ras.nacid.bg/dissertation-preview/75968
# [79/112] https://ras.nacid.bg/dissertation-preview/45501
# [80/112] https://ras.nacid.bg/dissertation-preview/15962
# [81/112] https://ras.nacid.bg/dissertation-preview/23029
# [82/112] https://ras.nacid.bg/dissertation-preview/13438
# [83/112] https://ras.nacid.bg/dissertation-preview/28444
# [84/112] https://ras.nacid.bg/dissertation-preview/27789
# [85/112] https://ras.nacid.bg/dissertation-preview/13467
# [86/112] https://ras.nacid.bg/dissertation-preview/2815
# [87/112] https://ras.nacid.bg/dissertation-preview/26054
# [88/112] https://ras.nacid.bg/dissertation-preview/39155
# [89/112] https://ras.nacid.bg/dissertation-preview/44638
# [90/112] https://ras.nacid.bg/dissertation-preview/37107
# [91/112] https://ras.nacid.bg/dissertation-preview/43023
# [92/112] https://ras.nacid.bg/dissertation-preview/25906
# [93/112] https://ras.nacid.bg/dissertation-preview/39239
# [94/112] https://ras.nacid.bg/dissertation-preview/69259
# [95/112] https://ras.nacid.bg/dissertation-preview/71818
# [96/112] https://ras.nacid.bg/dissertation-preview/15196
# [97/112] https://ras.nacid.bg/dissertation-preview/31268
# [98/112] https://ras.nacid.bg/dissertation-preview/16604
# [99/112] https://ras.nacid.bg/dissertation-preview/30968
# [100/112] https://ras.nacid.bg/dissertation-preview/28793
# [101/112] https://ras.nacid.bg/dissertation-preview/30422
# [102/112] https://ras.nacid.bg/dissertation-preview/45348
# [103/112] https://ras.nacid.bg/dissertation-preview/37448
# [104/112] https://ras.nacid.bg/dissertation-preview/30496
# [105/112] https://ras.nacid.bg/dissertation-preview/41554
# [106/112] https://ras.nacid.bg/dissertation-preview/28502
# [107/112] https://ras.nacid.bg/dissertation-preview/27917
# [108/112] https://ras.nacid.bg/dissertation-preview/27718
# [109/112] https://ras.nacid.bg/dissertation-preview/45889
# [110/112] https://ras.nacid.bg/dissertation-preview/79166
# [111/112] https://ras.nacid.bg/dissertation-preview/74682
# [112/112] https://ras.nacid.bg/dissertation-preview/43055
#
# DONE → FPhys_phd_plus_headers.xlsx

# %% [markdown]
# Check specifically whether the person studied outside of Bulgaria

# %%
import re
import asyncio
import pandas as pd
from datetime import datetime
from pathlib import Path
from playwright.async_api import async_playwright

# =====================
# SETTINGS (EDIT THESE)
# =====================
FILE = "inbreeding_at_FPhys.xlsx"
SHEET = "main_database"

NAME_COL = "Name"
LINK_COL = "NACID"

N_PEOPLE = 112

KEYWORDS = ("Асистент", "Главен асистент", "Доцент", "Професор", "Преподавател")

# =====================
# LOAD EXCEL
# =====================
path = Path(FILE)
if not path.exists():
    raise FileNotFoundError(f"File not found: {path.resolve()}")

df = pd.read_excel(path, sheet_name=SHEET)
df.columns = df.columns.astype(str).str.strip()

if LINK_COL not in df.columns:
    raise KeyError(f"Missing column '{LINK_COL}'. Columns present: {list(df.columns)}")

if NAME_COL not in df.columns:
    raise KeyError(
        f"Missing name column '{NAME_COL}'. "
        f"Set NAME_COL to one of: {list(df.columns)}"
    )

df[LINK_COL] = df[LINK_COL].astype(str).str.strip()
df[NAME_COL] = df[NAME_COL].astype(str).str.strip()

df = df[df[LINK_COL].str.contains("ras.nacid.bg", na=False)].copy()

# =====================
# HELPERS
# =====================
def norm(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "")).strip()

def clean_header_prefix(s: str) -> str:
    s = norm(s)
    return re.sub(r'^[^A-Za-zА-Яа-я0-9"„]+', "", s).strip()

def first_date(text: str):
    m = re.search(r"\b(\d{1,2}\.\d{1,2}\.\d{4})\b", text or "")
    return m.group(1) if m else None

def grab_stop(label_no_colon, text):
    labels = [
        "Висше училище", "Факултет", "Първично звено", "Научна степен",
        "Професионално направление", "Диплома No/дата", "Тема на дисертационния труд",
        # keep this list as-is for stop conditions; we’re not adding "Защитил в чужбина" here
        # because we only want to *detect presence* anywhere in the phd block
    ]
    nxt = "|".join(map(re.escape, labels))
    m = re.search(
        rf"{re.escape(label_no_colon)}\s*:\s*(.*?)(?=\s*(?:{nxt})\s*:|$)",
        text or "",
        flags=re.S
    )
    return norm(m.group(1)) if m else None

def award_date_from_diploma(text: str):
    line = grab_stop("Диплома No/дата", text)
    return first_date(line)

def sort_date(text):
    pattern = r'\d{1,2}.\d{1,2}.\d{4}'
    match = re.search(pattern, text)
    return datetime.strptime(match.group(), "%d.%m.%Y")

# =====================
# POSITIONS HEADER EXTRACTOR (NON-CLICK)
# =====================
async def get_section_container(page, section_title: str, exact):
    title_el = page.get_by_text(section_title, exact=exact).first
    await title_el.wait_for(timeout=60000)

    section = title_el.locator("xpath=ancestor::div[contains(@class,'card')][1]")
    if await section.count() == 0:
        section = title_el.locator("xpath=ancestor::div[2]")
    return section.first

async def find_position_headers(section):
    locators = [
        section.locator("css=mat-expansion-panel-header"),
        section.locator("css=.mat-expansion-panel-header"),
        section.locator("css=mat-expansion-panel .mat-expansion-panel-header"),
        section.locator("css=mat-expansion-panel [role='button']"),
        section.locator("css=[role='button']"),
    ]
    for loc in locators:
        try:
            if await loc.count() > 0:
                return loc
        except Exception:
            continue
    return section.locator("xpath=.//*")

def canonical_header(s: str) -> str:
    s = clean_header_prefix(s)
    s = norm(s)

    for k in KEYWORDS:
        m = re.search(rf"\s({re.escape(k)}\s*-)", s)
        if m and m.start() > 0:
            s = s[:m.start()].strip()

    return s

async def get_headers_in_section(page, section_title: str):
    section = await get_section_container(page, section_title, False)
    await section.scroll_into_view_if_needed()
    await asyncio.sleep(0.2)

    headers_loc = section.locator("css=mat-expansion-panel-header, .mat-expansion-panel-header")
    if await headers_loc.count() == 0:
        headers_loc = await find_position_headers(section)

    n = await headers_loc.count()

    out = []
    seen_keys = set()

    for i in range(n):
        h = headers_loc.nth(i)
        raw = norm(await h.inner_text())
        if not raw:
            continue
        if " - " not in raw:
            continue

        cleaned = canonical_header(raw)
        if not cleaned:
            continue
        if not any(cleaned.startswith(k) for k in KEYWORDS):
            continue

        key = cleaned.lower()
        if key in seen_keys:
            continue
        seen_keys.add(key)
        out.append(cleaned)

    return out

async def get_nested_date_in_header(page, header_title: str):
    section = await get_section_container(page, header_title, True)
    await section.scroll_into_view_if_needed()
    await asyncio.sleep(0.2)

    panel_heading_div = section.locator(".panel-heading")
    spanClickable = panel_heading_div.locator('.fa')
    classes = await spanClickable.get_attribute("class")
    expanded = 'fa-chevron-down' in (classes or "")

    if expanded != True:
        await spanClickable.click()

    next_div = panel_heading_div.locator("xpath=following-sibling::div[1]")
    headers_loc = next_div.locator(".row")

    if await headers_loc.count() == 0:
        headers_loc = await find_position_headers(section)

    n = await headers_loc.count()
    seen_keys = set()

    for i in range(n):
        h = headers_loc.nth(i)
        raw = norm(await h.inner_text())
        if not raw:
            continue

        cleaned = canonical_header(raw)
        if not cleaned:
            continue

        key = cleaned.lower()
        if key in seen_keys:
            continue
        seen_keys.add(key)

        pattern = r'\d{1,2}.\d{1,2}.\d{4}'
        if "Номер/дата на акт за назначаване" in cleaned:
            date = re.search(pattern, cleaned)
            return date.group() if date else None

    return None

async def safe_goto(page, url, tries=5):
    for attempt in range(tries):
        try:
            await page.goto(url, wait_until="domcontentloaded", timeout=60000)
            return True
        except Exception as e:
            msg = str(e)
            if ("ERR_" in msg or "Timeout" in msg):
                await asyncio.sleep(2 * (attempt + 1))
                continue
            raise
    return False

# =====================
# PERSON SCRAPER (PHD + HEADERS) + "Защитил в чужбина" CHECK
# =====================
async def scrape_person(page, url: str, row):
    # Returns: True/False (field present in ANY PhD panel), or None on fatal error
    try:
        ok = await safe_goto(page, url, 5)
        if not ok:
            row["ERROR"] = "Timeout loading page"
            return None
    except Exception as e:
        row["ERROR"] = str(e)
        return None

    defended_abroad_field_present = False

    try:
        # ----- PhD block -----
        loc = page.locator("h4.panel-title", has_text="Научни степени")
        await loc.wait_for(state="visible", timeout=60000)

        next_div = loc.locator("xpath=../following-sibling::div[1]")
        divPanels = await next_div.locator("div.panel-default").all()

        for div_panel in divPanels:
            clickable = div_panel.locator(".btn-block").first

            # expand only if not expanded (avoids toggling closed)
            aria = await clickable.get_attribute("aria-expanded")
            if aria != "true":
                await clickable.click()

            # wait for typical content inside the expanded panel (more reliable than diploma only)
            await div_panel.get_by_text("Научна степен", exact=False).wait_for(timeout=60000)

            # IMPORTANT: scan the ENTIRE panel text (this includes "Защитил в чужбина")
            panel_text = (await div_panel.inner_text()).replace("\u00a0", " ")

            if re.search(r"\bЗащитил\s+в\s+чужбина\b", panel_text, flags=re.IGNORECASE):
                defended_abroad_field_present = True
                # no need to keep scanning other phd panels
                break

    except Exception as e:
        row["ERROR"] = (row.get("ERROR", "") + " " + str(e)).strip()

    return defended_abroad_field_present


async def run(df):
    subset = df[[NAME_COL, LINK_COL]].dropna().head(N_PEOPLE).copy()
    total = len(subset)

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        for i, (name, url) in enumerate(zip(subset[NAME_COL], subset[LINK_COL]), start=1):
            # progress first (as before)
            print(f"[{i}/{total}] {url}")

            row = {"Name": name, "NACID_URL": url}
            present = await scrape_person(page, url, row)

            if present is None:
                print(f"{name} - ERROR: {row.get('ERROR','(unknown)')}")
            else:
                print(f"{name} - {'YES' if present else 'NO'}")

            await asyncio.sleep(0.6)

        await browser.close()

# =====================
# NOTEBOOK RUN
# =====================
# If you already have run_coro_in_thread(...) in your notebook, keep using it.
# Otherwise, use this simple fallback:
def run_coro_in_thread(coro):
    try:
        loop = asyncio.get_running_loop()
    except RuntimeError:
        loop = None

    if loop and loop.is_running():
        import threading
        def runner():
            asyncio.run(coro)
        t = threading.Thread(target=runner, daemon=True)
        t.start()
    else:
        asyncio.run(coro)

run_coro_in_thread(run(df))
# Out:
# [1/112] https://ras.nacid.bg/dissertation-preview/25762
# доц. д-р Евгени Овчаров - NO
# [2/112] https://ras.nacid.bg/dissertation-preview/22992
# доц. д-р Петко Недялков - NO
# [3/112] https://ras.nacid.bg/dissertation-preview/27215
# доц. д-р Тодор Велчев - NO
# [4/112] https://ras.nacid.bg/dissertation-preview/25775
# доц. д-р Антония Вълчева - NO
# [5/112] https://ras.nacid.bg/dissertation-preview/41613
# доц. д-р Владимир Божилов - NO
# [6/112] https://ras.nacid.bg/dissertation-preview/39622
# гл. ас. д-р Георги Петров - NO
# [7/112] https://ras.nacid.bg/dissertation-preview/46569
# гл. ас. д-р Орлин Станчев - NO
# [8/112] https://ras.nacid.bg/dissertation-preview/27581
# Доц. д-р Мариян Богомилов - NO
# [9/112] https://ras.nacid.bg/dissertation-preview/2802
# Проф. дфзн Георги Райновски - NO
# [10/112] https://ras.nacid.bg/dissertation-preview/2845
# Доц. д-р Илко Русинов - NO
# [11/112] https://ras.nacid.bg/dissertation-preview/26249
# Доц. д-р Стефан Лалковски - NO
# [12/112] https://ras.nacid.bg/dissertation-preview/36894
# Доц. д-р Красимир Митев - YES
# [13/112] https://ras.nacid.bg/dissertation-preview/29890
# Доц. д-р Калин Гладнишки - NO
# [14/112] https://ras.nacid.bg/dissertation-preview/30909
# Доц. д-р Борислав Павлов - NO
# [15/112] https://ras.nacid.bg/dissertation-preview/27272
# Доц. д-р Венелин Кожухаров - NO
# [16/112] https://ras.nacid.bg/dissertation-preview/25773
# Доц. д-р Пейчо Петков - NO
# [17/112] https://ras.nacid.bg/dissertation-preview/38604
# Доц. д-р Ивелина Димитрова - NO
# [18/112] https://ras.nacid.bg/dissertation-preview/39240
# Доц. д-р Страхил Георгиев - NO
# [19/112] https://ras.nacid.bg/dissertation-preview/47985
# Доц. д-р Диана Кочева - NO
# [20/112] https://ras.nacid.bg/dissertation-preview/36963
# Гл. ас. д-р Галина Ванкова-Кирилова - NO
# [21/112] https://ras.nacid.bg/dissertation-preview/42599
# Гл. ас. д-р Мартин Джонголов - YES
# [22/112] https://ras.nacid.bg/dissertation-preview/41142
# Гл. ас. д-р Николай Петров - NO
# [23/112] https://ras.nacid.bg/dissertation-preview/66774
# Гл. ас. д-р Момчил Найденов - NO
# [24/112] https://ras.nacid.bg/dissertation-preview/23127
# проф. дфзн Александър Драйшу - NO
# [25/112] https://ras.nacid.bg/dissertation-preview/15245
# доц. д-р Иван Бъчваров - NO
# [26/112] https://ras.nacid.bg/dissertation-preview/43809
# доц. д-р Любомир Стоянов - NO
# [27/112] https://ras.nacid.bg/dissertation-preview/40778
# гл. ас. д-р Наско Горунски - NO
# [28/112] https://ras.nacid.bg/dissertation-preview/41739
# гл. ас. д-р Николай Димитров - NO
# [29/112] https://ras.nacid.bg/dissertation-preview/66989
# гл. ас. д-р Мая Жекова - NO
# [30/112] https://ras.nacid.bg/dissertation-preview/27406
# доц. д-р Ренета Димитрова - NO
# [31/112] https://ras.nacid.bg/dissertation-preview/3567
# доц. д-р Николай Рачев - NO
# [32/112] https://ras.nacid.bg/dissertation-preview/25569
# доц. д-р Елисавета Пенева - NO
# [33/112] https://ras.nacid.bg/dissertation-preview/40438
# доц. д-р Гергана Герова - YES
# [34/112] https://ras.nacid.bg/dissertation-preview/29880
# доц. д-р Ренета Райкова - NO
# [35/112] https://ras.nacid.bg/dissertation-preview/23391
# доц. д-р Веселин Тончев - NO
# [36/112] https://ras.nacid.bg/dissertation-preview/28965
# гл. ас. д-р Милен Цеков - NO
# [37/112] https://ras.nacid.bg/dissertation-preview/39762
# гл. ас. д-р Венцислав Данчовски - NO
# [38/112] https://ras.nacid.bg/dissertation-preview/39761
# гл. ас. д-р Савка Петрова - NO
# [39/112] https://ras.nacid.bg/dissertation-preview/41494
# гл. ас. д-р Гергана Георгиева - NO
# [40/112] https://ras.nacid.bg/dissertation-preview/49309
# физик д-р Люба Димова - NO
# [41/112] https://ras.nacid.bg/dissertation-preview/44555
# доц. д-р Ивелина Коцева-Георгиева - NO
# [42/112] https://ras.nacid.bg/dissertation-preview/27621
# доц. д-р Христина Андреева - NO
# [43/112] https://ras.nacid.bg/dissertation-preview/26967
# гл. ас. д-р Весела Димова - NO
# [44/112] https://ras.nacid.bg/dissertation-preview/45784
# гл.ас. д-р Лъчезар Симеонов - NO
# [45/112] https://ras.nacid.bg/dissertation-preview/68416
# гл. ас. д-р Милена Стоянова - NO
# [46/112] https://ras.nacid.bg/dissertation-preview/46236
# гл. ас. д-р Александър Куртенков - NO
# [47/112] https://ras.nacid.bg/dissertation-preview/73548
# гл. ас. д-р Фабиен Кунис - NO
# [48/112] https://ras.nacid.bg/dissertation-preview/39760
# доц. д-р Христо Илиев - NO
# [49/112] https://ras.nacid.bg/dissertation-preview/23230
# проф. дфзн Виктор Иванов - NO
# [50/112] https://ras.nacid.bg/dissertation-preview/44059
